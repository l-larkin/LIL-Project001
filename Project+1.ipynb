# %% [markdown]
# # Explore the data for the DC_Properties.csv dataset. Begin to prepare the data (clean, manipulate, transform, etc.) for future analysis. What interesting things can you conclude about the data?

# %%
PROJECT 1 - LARRY LARKIN

# %% [markdown]
# # import data
# import pandas as pd
# location = "datasets/datasets/DC_Properties.csv"
# df = pd.read_csv(location)

# %%
df.shape
# Out:
# (158957, 49)

# %%
# Find out what's missing
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
# Look for duplicates
df.duplicated(['FULLADDRESS'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927     True
# 158928     True
# 158929     True
# 158930     True
# 158931     True
# 158932     True
# 158933     True
# 158934     True
# 158935     True
# 158936     True
# 158937     True
# 158938     True
# 158939     True
# 158940     True
# 158941     True
# 158942     True
# 158943     True
# 158944     True
# 158945     True
# 158946     True
# 158947     True
# 158948     True
# 158949     True
# 158950     True
# ...

# %%
dfmean = df['PRICE'].mean()
dfmean
# Out:
# 931351.5949336156

# %%
df[df["CNDTN"]=="Poor"]["PRICE"].mean()
# Out:
# 474262.63440860214

# %%
df[df["PRICE"]<50000]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 25              25       1          0  Hot Water Rad  N        1.0      8
# 433            433       3          0  Hot Water Rad  N        3.0     11
# 638            638       2          0      Warm Cool  Y        1.0      9
# 1186          1186       2          0     Forced Air  Y        2.0      6
# 1567          1567       3          0  Hot Water Rad  N        2.0     11
# 1593          1593       1          0  Hot Water Rad  N        1.0      5
# 1916          1916       4          0  Hot Water Rad  N        2.0     12
# 2446          2446       2          0  Hot Water Rad  N        1.0     10
# 2681          2681       3          0  Hot Water Rad  N        2.0     12
# 3293          3293       2          0     Forced Air  N        2.0      7
# 3330          3330       2          1  Hot Water Rad  N        1.0      9
# ...

# %%
df[df["PRICE"]<50000]["ROOMS"].mean()
# Out:
# 4.8061056105610565

# %%
df[df["BATHRM"]==4]["PRICE"].mean()
# Out:
# 958108.1412689285

# %%
df[(df["PRICE"] < 50000) ["EYB"].max()
# Out:
# 2018

# %%
df[(df["PRICE"] < 50000) & (df["EYB"]== 2018)]
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 85573       85573       6          2  Forced Air  Y        2.0     12      6
#
#           AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 85573  2018.0      NaN   ...    -76.944476         Deanwood
#
#       ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 85573     018 A Deanwood        7803.0  007803 1009  Ward 7    5077
#
#                X          Y QUADRANT
# 85573 -76.944482  38.898914       NE
#
# [1 rows x 49 columns]

# %%
df[df["BATHRM"]==4]["PRICE"].max()
# Out:
# 25100000.0

# %%
df[(df["PRICE"] < 1000000) & (df["ROOMS"] > 8)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 27              27       3          0  Hot Water Rad  Y        4.0      9
# 45              45       3          1     Forced Air  Y        2.0     10
# 46              46       3          1      Warm Cool  Y        2.0      9
# 59              59       2          0  Hot Water Rad  N        2.0      9
# 69              69       3          1  Hot Water Rad  N        3.0     10
# 70              70       3          0     Forced Air  Y        2.0     10
# 76              76       2          1      Warm Cool  Y        2.0     11
# 77              77       2          1      Warm Cool  Y        2.0     11
# 85              85       3          1  Hot Water Rad  Y        2.0      9
# 97              97       4          0      Warm Cool  Y        4.0     12
# ...
